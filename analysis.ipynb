# %%
#pip install -r requirements.txt

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.preprocess import download_from_s3, load_data, preprocess_data
from src.train import train_model, save_model
from src.evaluate import predict_and_prepare_submission

# %% [markdown]
# # 1. Download and load data

# %%
download_from_s3('keithsbucketaws', 'rossmann-data/', 'data', ['train.csv', 'test.csv', 'store.csv'])
train, test, store = load_data('data')
# Out:
# ✅ Downloaded train.csv to data/train.csv
# ✅ Downloaded test.csv to data/test.csv
# ✅ Downloaded store.csv to data/store.csv

# %% [markdown]
# # 2. Preprocess

# %%
X_train, y_train, X_test, test_store = preprocess_data(train, test, store)

# %% [markdown]
# # 3. Train

# %%
model = train_model(X_train, y_train)
# Out:
# ✅ Model training complete.

# %% [markdown]
# # 4. Save

# %%
save_model(model, 'models/rossmann_xgb.pkl')
# Out:
# 💾 Model saved to models/rossmann_xgb.pkl

# %% [markdown]
# # 5. Predict & Save submission

# %%
predict_and_prepare_submission(model, X_test, test_store)
# Out:
# ✅ Submission file saved as data/rossmann_submission.csv
